# %%
twitter_access_token="1450132249530171395-HQm3zbXBhy4QmLXTztSohTfkvGhy2m"
twitter_access_secret ="rR1AZd1nBtZEfhvk0tU2jePNesl2cgxCO4gNYV17BLjC0"
twitter_consumer_key = "hRSJY5XNlWfEDaT4KDTxB3epf"
twitter_consumer_secret = "cLstbiL7hJkwrFoaB9crgsoDVEKLXGUGvqCR8ZSYgaAiKtfG7k"  
import twitter
import pandas as pd
twitter_api = twitter.Api(consumer_key=twitter_consumer_key,
                          consumer_secret=twitter_consumer_secret, 
                          access_token_key=twitter_access_token, 
                          access_token_secret=twitter_access_secret)
df=pd.DataFrame(columns=['text','label'])
query = "bitcoin"
statuses = twitter_api.GetSearch(term=query, count=1000)
for status in statuses:
    df.loc[len(df)]=[status.text,'0']
df.to_csv('C:\\Users\\user\\bicoin8.csv',sep=',',na_rep='NaN')

# %%
df
# Out:
#                                                  text label
# 0   VC guys keep trying to make cryptocurrency a g...     0
# 1   @Filasophical @ShibaInuHodler Out of curiosity...     0
# 2   Someone moved $1 billion of Bitcoin last week ...     0
# 3   RT @KayahanKaraman: Tekrar bir çekiliş yapıyor...     0
# 4   RT @Freshdipo1: Do You Want To Promote Or Grow...     0
# ..                                                ...   ...
# 91  🔥🔥🔥 🐳🚨 Bitcoin Whale Alert: [ TX: b2b6c1fcb9ee...     0
# 92  RT @LeJournalDuCoin: Pour fêter nos 100 000 fo...     0
# 93              @Bitcoin @cryptocharts_M @elonmusk 🔥💯     0
# 94  RT @Limburg3rt: @Xentagz NO MINER WILL EVER RE...     0
# 95  RT @PigBossToken: 🔥 Pigboss Airdrop (Pigboss)\...     0
#
# [96 rows x 2 columns]
